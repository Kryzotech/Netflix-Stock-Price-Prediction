# %%
import pandas as pd
# Out:
# C:\Users\Abdur rahim nishad\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Abdur rahim nishad\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Abdur rahim nishad\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df=pd.read_csv("netflix .csv")

# %%
df
# Out:
#            Open       High        Low      Close  Adj Close    Volume  Year  \
# 0     262.00000  267.89999  250.02999  254.25999  254.25999  11896100  2018
# 1     247.69999  266.70001  245.00000  265.72000  265.72000  12595800  2018
# 2     266.57998  272.45001  264.32998  264.55999  264.55999   8981500  2018
# 3     267.07998  267.61999  250.00000  250.10000  250.10000   9306700  2018
# 4     253.85000  255.80000  236.11000  249.47000  249.47000  16906900  2018
# ...         ...        ...        ...        ...        ...       ...   ...
# 1004  401.97000  427.70001  398.20001  427.14001  427.14001  20047500  2022
# 1005  432.95999  458.48001  425.54000  457.13000  457.13000  22542300  2022
# 1006  448.25000  451.98001  426.48001  429.48001  429.48001  14346000  2022
# 1007  421.44000  429.26001  404.27999  405.60000  405.60000   9905200  2022
# 1008  407.30999  412.76998  396.64001  410.17001  410.17001   7782400  2022
#
#       Month  Day
# 0         2    5
# 1         2    6
# ...

# %%
df2=pd.read_csv(r"D:\kryzotect\netflix2.csv")

# %%
df2.head()
# Out:
#         Open       High        Low      Close  Adj Close    Volume  Year  \
# 0  262.00000  267.89999  250.02999  254.25999  254.25999  11896100  2018
# 1  247.69999  266.70001  245.00000  265.72000  265.72000  12595800  2018
# 2  266.57998  272.45001  264.32998  264.55999  264.55999   8981500  2018
# 3  267.07998  267.61999  250.00000  250.10000  250.10000   9306700  2018
# 4  253.85000  255.80000  236.11000  249.47000  249.47000  16906900  2018
#
#    Month  Day        Date
# 0      2    5  2018-02-05
# 1      2    6  2018-02-06
# 2      2    7  2018-02-07
# 3      2    8  2018-02-08
# 4      2    9  2018-02-09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1009 non-null   float64
#  1   High       1009 non-null   float64
#  2   Low        1009 non-null   float64
#  3   Close      1009 non-null   float64
#  4   Adj Close  1009 non-null   float64
#  5   Volume     1009 non-null   int64
#  6   Year       1009 non-null   int64
#  7   Month      1009 non-null   int64
#  8   Day        1009 non-null   int64
# dtypes: float64(5), int64(4)
# memory usage: 71.1 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df)

# %%
def style():
    plt.figure(facecolor='black', figsize=(15,10))
    ax = plt.axes()

    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to white
    ax.tick_params(axis='y', colors='white')    #setting up Y-axis tick color to white

    ax.spines['left'].set_color('white')        #setting up Y-axis spine color to white
    #ax.spines['right'].set_color('white')
    #ax.spines['top'].set_color('white')
    ax.spines['bottom'].set_color('white')      #setting up X-axis spine color to white

    ax.set_facecolor("black")

# %%
viz = df2.copy()

# %%
viz['Date']=pd.to_datetime(viz['Date'],format='%Y-%m-%d')

# %%
data = pd.DataFrame(viz[['Date','Close']])
data=data.reset_index()
data=data.drop('index',axis=1)
data.set_index('Date', inplace=True)
data = data.asfreq('D')
data
# Out:
#                 Close
# Date
# 2018-02-05  254.25999
# 2018-02-06  265.72000
# 2018-02-07  264.55999
# 2018-02-08  250.10000
# 2018-02-09  249.47000
# ...               ...
# 2022-01-31  427.14001
# 2022-02-01  457.13000
# 2022-02-02  429.48001
# 2022-02-03  405.60000
# 2022-02-04  410.17001
#
# [1461 rows x 1 columns]

# %%
style()

plt.title('Closing Stock Price', color="white",fontweight='bold', fontsize=16)
plt.plot(viz.Date, viz.Close, color="#94F008")
plt.legend(["Close"], loc ="lower right", facecolor='black', labelcolor='white')

# %%
for i in df.columns:
    plt.figure(figsize=(10,6))
    sns.distplot(df[i])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\Abdur rahim nishad\AppData\Local\Temp\ipykernel_11120\628104510.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\Abdur rahim nishad\AppData\Local\Temp\ipykernel_11120\628104510.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(df['Close'])
# Out:
# <Axes: >

# %%
sns.boxplot(x="Open", y="Close", data=df)
# Out:
# <Axes: xlabel='Open', ylabel='Close'>

# %%
sns.scatterplot(x='Volume',y='Year',data=df)
# Out:
# <Axes: xlabel='Volume', ylabel='Year'>

# %%
# Plot the volume over time
plt.figure(figsize=(14,7))
plt.plot(df2['Date'], df2['Volume'])
plt.title('Netflix Trading Volume Over Time', fontweight='bold', fontsize=16)
plt.xlabel('Date',fontweight='bold')
plt.ylabel('Volume',fontweight='bold')
plt.show()

# %%
# Plot a histogram of the closing prices
plt.figure(figsize=(10,6))
plt.hist(df2['Close'], bins=30, alpha=0.75)
plt.title('Distribution of Netflix Closing Stock Prices',fontweight='bold', fontsize=16)
plt.xlabel('Closing Price (USD)',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.grid(True)
plt.show()

# %%
df2=pd.read_csv(r"D:\kryzotect\netflix2.csv")

# %%
# Calculate descriptive statistics
numeric_stats = df2[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].describe()

mean_values = numeric_stats.loc['mean'] 
std_deviation = numeric_stats.loc['std'] 
min_values = numeric_stats.loc['min'] 
max_values = numeric_stats.loc['max']

# %%
mean_values
# Out:
# Open         4.190597e+02
# High         4.253207e+02
# Low          4.123740e+02
# Close        4.190007e+02
# Adj Close    4.190007e+02
# Volume       7.570685e+06
# Name: mean, dtype: float64

# %%
for i in mean_values:
    print(i)
# Out:
# 419.0596693557978
# 425.320699395441
# 412.3740397224975
# 419.00072846382557
# 419.00072846382557
# 7570685.03468781

# %%
std_deviation
# Out:
# Open         1.085375e+02
# High         1.092630e+02
# Low          1.075559e+02
# Close        1.082900e+02
# Adj Close    1.082900e+02
# Volume       5.465535e+06
# Name: std, dtype: float64

# %%
for i in std_deviation:
    print(i)
# Out:
# 108.53753194531917
# 109.26295960161592
# 107.55586757376079
# 108.28999879404391
# 108.28999879404391
# 5465535.2256899765

# %%
min_values
# Out:
# Open         2.339200e+02
# High         2.506500e+02
# Low          2.312300e+02
# Close        2.338800e+02
# Adj Close    2.338800e+02
# Volume       1.144000e+06
# Name: min, dtype: float64

# %%
max_values
# Out:
# Open         6.923500e+02
# High         7.009900e+02
# Low          6.860900e+02
# Close        6.916900e+02
# Adj Close    6.916900e+02
# Volume       5.890430e+07
# Name: max, dtype: float64

# %%
for i in min_values:
    print(i)
# Out:
# 233.91999
# 250.64999
# 231.22999
# 233.88
# 233.88
# 1144000.0

# %%
for i in max_values:
    print(i)
# Out:
# 692.34997
# 700.98999
# 686.09002
# 691.69
# 691.69
# 58904300.0

# %%
import matplotlib.pyplot as plt

# Example: Creating a histogram for the 'Close' column
plt.hist(df2['Close'], bins=20)  # Adjust the number of bins as needed
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.title('Distribution of Close Prices',fontweight='bold', fontsize=16)
plt.show()

# %%
for i in df.columns:
#     plt.figure(figsize=(10,6))
    sns.distplot(df[i])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\Abdur rahim nishad\AppData\Local\Temp\ipykernel_11116\3054516971.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\Abdur rahim nishad\AppData\Local\Temp\ipykernel_11116\3054516971.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
